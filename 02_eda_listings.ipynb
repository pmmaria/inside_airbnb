# %% [markdown]
# # Analysis of Listings - Inside Airbnb Santiago
#
# ## 1. Introduction
#
# This notebook details the process of cleaning and preparing the `listings.csv` dataset from the Inside Airbnb project for further analysis. The focus is on:
#
# - Removing redundant or irrelevant columns
# - Handling missing values
# - Converting and standardizing key features (especially pricing)
# - Flagging outliers
# - Preparing a clean dataset for use in the final analysis
#
#
# ## 2. Load and Preview
# In this section, we will load the listings dataset, examine its dimensions and structure, and perform an initial check for missing values. Specifically, we will:
#
# - Load the dataset from the local folder.
# - Display the shape and data types of the dataframe.
# - Show a preview of the first few rows.
# - Summarize missing values by column.

# %%
import pandas as pd

# Load the listings data from a gzipped CSV file
df_listings = pd.read_csv('santiago/listings.csv.gz', compression='gzip') 


# Preview the data
print("\n----Preview:\n")
with pd.option_context('display.max_columns', None):
    display(df_listings.head())  # Or any slice, e.g., df_listings.iloc[:, :10]

print("\n----Info:\n")
df_listings.info()

print("\n----Shape:\n")
print(df_listings.shape)

# Check for missing values
missing = df_listings.isnull().sum()
missing = missing[missing > 0]  # only show columns with missing values
print("\n----Columns with Missing Values:\n")
print(missing)
# Out:
# ----Preview:
#        id                          listing_url       scrape_id last_scraped  \
# 0   49392   https://www.airbnb.com/rooms/49392  20241227033155   2024-12-27
# 1   52811   https://www.airbnb.com/rooms/52811  20241227033155   2024-12-27
# 2   53494   https://www.airbnb.com/rooms/53494  20241227033155   2024-12-27
# 3  787045  https://www.airbnb.com/rooms/787045  20241227033155   2024-12-27
# 4  795701  https://www.airbnb.com/rooms/795701  20241227033155   2024-12-27
#
#         source                                name  \
# 0  city scrape        Share my Flat in Providencia
# 1  city scrape  Suite Providencia 1 Santiago Chile
# 2  city scrape  depto centro ski el colorado chile
# 3  city scrape                       right at home
# 4  city scrape           Lindo Depto 2 dormitorios
#
#                                          description  \
# 0                                                NaN
# 1  Apartment located on the subway station Manuel...
# 2                                                NaN
# 3  A few steps from metro station "FERNANDO CASTI...
# 4  Nice and comfortable two-bedroom apartment. Fu...
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1  Building located on the access to the Manuel M...
# 2                                                NaN
# 3  Metro Station " FERNANDO CASTILLO" (LINE 3)" i...
# 4  Centrally located by day works commercially, a...
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/3740612/b1850...   224592
# 1  https://a0.muscache.com/pictures/miso/Hosting-...   244792
# 2  https://a0.muscache.com/pictures/310936/ff7d53...   249097
# 3  https://a0.muscache.com/pictures/airflow/Hosti...  4134987
# 4  https://a0.muscache.com/pictures/14703811/def2...  4191304
#
#                                     host_url host_name  host_since  \
# 0   https://www.airbnb.com/users/show/224592     Maria  2010-09-05
# 1   https://www.airbnb.com/users/show/244792  Cristián  2010-09-25
# 2   https://www.airbnb.com/users/show/249097   Paulina  2010-09-29
# 3  https://www.airbnb.com/users/show/4134987     Mirey  2012-11-13
# 4  https://www.airbnb.com/users/show/4191304     Doris  2012-11-19
#
#                          host_location  \
# 0                   Providencia, Chile
# 1  Santiago Metropolitan Region, Chile
# 2                                  NaN
# 3                      Santiago, Chile
# 4                                Chile
#
#                                           host_about  host_response_time  \
# 0  Disfruto viajando, sobre todo a lugares donde ...                 NaN
# 1  Un tipo profesional, trabajador, sencillo, con...                 NaN
# 2                       Soy dentista, casada,4 hijos        within a day
# 3  I love getting guests at home and to meet peop...      within an hour
# 4  Soy muy atenta y cordial. Viví en Barcelona mu...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                  NaN                 f
# 1                NaN                   0%                 f
# 2               100%                  75%                 f
# 3               100%                  79%                 t
# 4               100%                  66%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/bd1a8...
# 1  https://a0.muscache.com/im/users/244792/profil...
# 2  https://a0.muscache.com/im/pictures/user/6d0ff...
# 3  https://a0.muscache.com/im/pictures/user/User-...
# 4  https://a0.muscache.com/im/pictures/user/User-...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/user/bd1a8...                NaN
# 1  https://a0.muscache.com/im/users/244792/profil...                NaN
# 2  https://a0.muscache.com/im/pictures/user/6d0ff...                NaN
# 3  https://a0.muscache.com/im/pictures/user/User-...                NaN
# 4  https://a0.muscache.com/im/pictures/user/User-...                NaN
#
#    host_listings_count  host_total_listings_count  \
# 0                    2                          3
# 1                    3                          4
# 2                    2                          2
# 3                    3                          3
# 4                    3                          5
#
#                  host_verifications host_has_profile_pic  \
# 0                ['email', 'phone']                    t
# 1  ['email', 'phone', 'work_email']                    t
# 2                ['email', 'phone']                    t
# 3                ['email', 'phone']                    t
# 4  ['email', 'phone', 'work_email']                    t
#
#   host_identity_verified                                  neighbourhood  \
# 0                      t                                            NaN
# 1                      t       Providencia, Región Metropolitana, Chile
# 2                      t                                            NaN
# 3                      t  Santiago, Santiago Metropolitan Region, Chile
# 4                      t  Santiago, Santiago Metropolitan Region, Chile
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed  latitude  longitude  \
# 0            Providencia                           NaN -33.43277  -70.59892
# 1            Providencia                           NaN -33.42959  -70.61880
# 2           Lo Barnechea                           NaN -33.34521  -70.29543
# 3               La Reina                           NaN -33.45534  -70.56020
# 4               Santiago                           NaN -33.43989  -70.65717
#
#                  property_type        room_type  accommodates  bathrooms  \
# 0  Private room in rental unit     Private room             1        NaN
# 1           Entire rental unit  Entire home/apt             4        1.0
# 2           Entire rental unit  Entire home/apt             6        2.0
# 3         Private room in home     Private room             2        1.0
# 4           Entire rental unit  Entire home/apt             5        2.0
#
#    bathrooms_text  bedrooms  beds  \
# 0             NaN       1.0   1.0
# 1          1 bath       1.0   1.0
# 2         2 baths       2.0   8.0
# 3  1 private bath       1.0   1.0
# 4         2 baths       2.0   4.0
#
#                                            amenities        price  \
# 0                                                 []   $52,420.00
# 1  ["First aid kit", "Iron", "Host greets you", "...   $53,409.00
# 2  ["Essentials", "Heating", "TV with standard ca...  $149,999.00
# 3  ["Pocket wifi", "Shared pool", "First aid kit"...   $19,000.00
# 4  ["Essentials", "Heating", "Dishes and silverwa...   $53,409.00
#
#    minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0               3             730                       3
# 1               1            1825                       1
# 2               2             730                       2
# 3               5              30                       5
# 4               2              30                       2
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       3                     730                     730
# 1                       1                    1125                    1125
# 2                       2                     730                     730
# 3                       5                      30                      30
# 4                       2                      30                      30
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                     3.0                   730.0               NaN
# 1                     1.0                  1125.0               NaN
# 2                     2.0                   730.0               NaN
# 3                     5.0                    30.0               NaN
# 4                     2.0                    30.0               NaN
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               28               58               88
# 1                t                0                0                0
# 2                t               30               60               90
# 3                t               29               59               89
# 4                t               29               59               89
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0               178            2024-12-27                  0
# 1                 0            2024-12-27                 45
# 2               365            2024-12-27                 48
# 3               269            2024-12-27                148
# 4               364            2024-12-27                 29
#
#    number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                      0                       0          NaN         NaN
# 1                      0                       0   2010-11-13  2021-11-04
# 2                     11                       0   2016-07-04  2024-09-01
# 3                     16                       1   2012-11-26  2024-11-30
# 4                      2                       0   2013-01-04  2024-07-23
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                   NaN                     NaN                        NaN
# 1                  4.42                    4.59                       4.52
# 2                  4.77                    4.81                       4.90
# 3                  4.82                    4.89                       4.86
# 4                  4.66                    4.62                       4.72
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                    NaN                          NaN                     NaN
# 1                   4.66                         4.59                    4.64
# 2                   4.88                         4.88                    4.79
# 3                   4.94                         4.93                    4.66
# 4                   4.86                         4.86                    4.55
#
#    review_scores_value license instant_bookable  \
# 0                  NaN     NaN                f
# 1                 4.36     NaN                t
# 2                 4.69     NaN                f
# 3                 4.85     NaN                f
# 4                 4.69     NaN                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               3
# 2                               1
# 3                               2
# 4                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            3
# 2                                            1
# 3                                            0
# 4                                            2
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             0
# 2                                             0
# 3                                             2
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0                NaN
# 1                                            0               0.26
# 2                                            0               0.46
# 3                                            0               1.01
# 4                                            0               0.20
# ----Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15051 entries, 0 to 15050
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            15051 non-null  int64
#  1   listing_url                                   15051 non-null  object
#  2   scrape_id                                     15051 non-null  int64
#  3   last_scraped                                  15051 non-null  object
#  4   source                                        15051 non-null  object
#  5   name                                          15051 non-null  object
#  6   description                                   14533 non-null  object
#  7   neighborhood_overview                         5588 non-null   object
#  8   picture_url                                   15051 non-null  object
#  9   host_id                                       15051 non-null  int64
#  10  host_url                                      15051 non-null  object
#  11  host_name                                     15051 non-null  object
#  12  host_since                                    15051 non-null  object
#  13  host_location                                 10260 non-null  object
#  14  host_about                                    6609 non-null   object
#  15  host_response_time                            12180 non-null  object
#  16  host_response_rate                            12180 non-null  object
#  17  host_acceptance_rate                          12636 non-null  object
#  18  host_is_superhost                             14719 non-null  object
#  19  host_thumbnail_url                            15051 non-null  object
#  20  host_picture_url                              15051 non-null  object
#  21  host_neighbourhood                            2777 non-null   object
#  22  host_listings_count                           15051 non-null  int64
#  23  host_total_listings_count                     15051 non-null  int64
#  24  host_verifications                            15051 non-null  object
#  25  host_has_profile_pic                          15051 non-null  object
#  26  host_identity_verified                        15051 non-null  object
#  27  neighbourhood                                 5588 non-null   object
#  28  neighbourhood_cleansed                        15051 non-null  object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      15051 non-null  float64
#  31  longitude                                     15051 non-null  float64
#  32  property_type                                 15051 non-null  object
#  33  room_type                                     15051 non-null  object
#  34  accommodates                                  15051 non-null  int64
#  35  bathrooms                                     13053 non-null  float64
#  36  bathrooms_text                                15027 non-null  object
#  37  bedrooms                                      14257 non-null  float64
#  38  beds                                          13044 non-null  float64
#  39  amenities                                     15051 non-null  object
#  40  price                                         13062 non-null  object
#  41  minimum_nights                                15051 non-null  int64
#  42  maximum_nights                                15051 non-null  int64
#  43  minimum_minimum_nights                        15051 non-null  int64
#  44  maximum_minimum_nights                        15051 non-null  int64
#  45  minimum_maximum_nights                        15051 non-null  int64
#  46  maximum_maximum_nights                        15051 non-null  int64
#  47  minimum_nights_avg_ntm                        15051 non-null  float64
#  48  maximum_nights_avg_ntm                        15051 non-null  float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              13970 non-null  object
#  51  availability_30                               15051 non-null  int64
#  52  availability_60                               15051 non-null  int64
#  53  availability_90                               15051 non-null  int64
#  54  availability_365                              15051 non-null  int64
#  55  calendar_last_scraped                         15051 non-null  object
#  56  number_of_reviews                             15051 non-null  int64
#  57  number_of_reviews_ltm                         15051 non-null  int64
#  58  number_of_reviews_l30d                        15051 non-null  int64
#  59  first_review                                  11807 non-null  object
#  60  last_review                                   11807 non-null  object
#  61  review_scores_rating                          11807 non-null  float64
#  62  review_scores_accuracy                        11807 non-null  float64
#  63  review_scores_cleanliness                     11807 non-null  float64
#  64  review_scores_checkin                         11807 non-null  float64
#  65  review_scores_communication                   11807 non-null  float64
#  66  review_scores_location                        11806 non-null  float64
#  67  review_scores_value                           11807 non-null  float64
#  68  license                                       167 non-null    object
#  69  instant_bookable                              15051 non-null  object
#  70  calculated_host_listings_count                15051 non-null  int64
#  71  calculated_host_listings_count_entire_homes   15051 non-null  int64
#  72  calculated_host_listings_count_private_rooms  15051 non-null  int64
#  73  calculated_host_listings_count_shared_rooms   15051 non-null  int64
#  74  reviews_per_month                             11807 non-null  float64
# dtypes: float64(17), int64(23), object(35)
# memory usage: 8.6+ MB
#
# ----Shape:
#
# (15051, 75)
#
# ----Columns with Missing Values:
#
# description                       518
# neighborhood_overview            9463
# host_location                    4791
# host_about                       8442
# host_response_time               2871
# host_response_rate               2871
# host_acceptance_rate             2415
# host_is_superhost                 332
# host_neighbourhood              12274
# neighbourhood                    9463
# neighbourhood_group_cleansed    15051
# bathrooms                        1998
# bathrooms_text                     24
# bedrooms                          794
# beds                             2007
# price                            1989
# calendar_updated                15051
# has_availability                 1081
# first_review                     3244
# last_review                      3244
# review_scores_rating             3244
# review_scores_accuracy           3244
# review_scores_cleanliness        3244
# review_scores_checkin            3244
# review_scores_communication      3244
# review_scores_location           3245
# review_scores_value              3244
# license                         14884
# reviews_per_month                3244
# dtype: int64

# %% [markdown]
# #### Observations
#
# - The listings table contains 15,051 records and 75 columns.
#
# - Columns include information about the listings location, hosts, facilities, minimum/maximum nights, price, reviews score and data about the scrape process among other things.
#
# - Many columns contain data that is not relevant for this analysis. Those will be drop from the DataFrame
#
# - There are many columns with missing values that I need to handle.
#
# - In order to have a preview of all the DataFrame, I will split the table

# %% [markdown]
# ## 3. Cleaning
#
# In this section, I will clean the listings dataset by:
#
# - Dropping irrelevant columns.
# - Converting data types to appropriate formats.
# - Handling missing values.
# - Adding `price_usd` column.
# - Renaming columns for clarity and consistency
#
# ### 3.1 Drop irrelevant columns
#
# There are several columns to drop:
#
# There are multiple columns regarding the minimum and maximum nights:
#
# - **`minimum_nights`**: Minimum nights required to book. Often useful in filtering listings that only accept longer stays
#
# - **`maximum_nights`**: Maximum nights allowed per booking. Helps understand stay limits
#
# - **`minimum_minimum_nights`**: Min value of minimum_nights across 12 months. Very specific and probably not needed unless doing time-series
#
# - **`maximum_minimum_nights`**: Max value of minimum_nights across 12 months. Same as above.
#
# - **`minimum_maximum_nights`**: Min value of maximum_nights across 12 months. Too granular for most analyses
#
# - **`minimum_nights_avg_ntm`**: Avg monthly minimum_nights. Very specific
#
# - **`maximum_nights_avg_ntm`**: Avg monthly maximum_nights. Same as above

# %%
# Drop unnecessary columns
columns_to_drop = [
    'scrape_id',
    'last_scraped',
    'source',
    'picture_url',
    'neighbourhood', # This column contains similar information to 'neighbourhood_cleansed'
    'neighbourhood_group_cleansed', # This column has no data
    'host_has_profile_pic',
    'host_thumbnail_url',
    'host_picture_url',
    'host_neighbourhood',
    'host_verifications',
    'host_has_profile_pic',
    'calendar_updated', #This column has no data
    'calendar_last_scraped',
    'license',
    'minimum_minimum_nights', 
    'maximum_minimum_nights',
    'minimum_maximum_nights',
    'maximum_maximum_nights',
    'minimum_nights_avg_ntm',
    'maximum_nights_avg_ntm'
]
# Drop the columns
df_listings.drop(columns=columns_to_drop, inplace=True)
# Reset index after dropping columns
df_listings.reset_index(drop=True, inplace=True)

# Print the cleaned data info
print("\n----Cleaned Data Info:\n")
df_listings.info()
# Out:
# ----Cleaned Data Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15051 entries, 0 to 15050
# Data columns (total 55 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            15051 non-null  int64
#  1   listing_url                                   15051 non-null  object
#  2   name                                          15051 non-null  object
#  3   description                                   14533 non-null  object
#  4   neighborhood_overview                         5588 non-null   object
#  5   host_id                                       15051 non-null  int64
#  6   host_url                                      15051 non-null  object
#  7   host_name                                     15051 non-null  object
#  8   host_since                                    15051 non-null  object
#  9   host_location                                 10260 non-null  object
#  10  host_about                                    6609 non-null   object
#  11  host_response_time                            12180 non-null  object
#  12  host_response_rate                            12180 non-null  object
#  13  host_acceptance_rate                          12636 non-null  object
#  14  host_is_superhost                             14719 non-null  object
#  15  host_listings_count                           15051 non-null  int64
#  16  host_total_listings_count                     15051 non-null  int64
#  17  host_identity_verified                        15051 non-null  object
#  18  neighbourhood_cleansed                        15051 non-null  object
#  19  latitude                                      15051 non-null  float64
#  20  longitude                                     15051 non-null  float64
#  21  property_type                                 15051 non-null  object
#  22  room_type                                     15051 non-null  object
#  23  accommodates                                  15051 non-null  int64
#  24  bathrooms                                     13053 non-null  float64
#  25  bathrooms_text                                15027 non-null  object
#  26  bedrooms                                      14257 non-null  float64
#  27  beds                                          13044 non-null  float64
#  28  amenities                                     15051 non-null  object
#  29  price                                         13062 non-null  object
#  30  minimum_nights                                15051 non-null  int64
#  31  maximum_nights                                15051 non-null  int64
#  32  has_availability                              13970 non-null  object
#  33  availability_30                               15051 non-null  int64
#  34  availability_60                               15051 non-null  int64
#  35  availability_90                               15051 non-null  int64
#  36  availability_365                              15051 non-null  int64
#  37  number_of_reviews                             15051 non-null  int64
#  38  number_of_reviews_ltm                         15051 non-null  int64
#  39  number_of_reviews_l30d                        15051 non-null  int64
#  40  first_review                                  11807 non-null  object
#  41  last_review                                   11807 non-null  object
#  42  review_scores_rating                          11807 non-null  float64
#  43  review_scores_accuracy                        11807 non-null  float64
#  44  review_scores_cleanliness                     11807 non-null  float64
#  45  review_scores_checkin                         11807 non-null  float64
#  46  review_scores_communication                   11807 non-null  float64
#  47  review_scores_location                        11806 non-null  float64
#  48  review_scores_value                           11807 non-null  float64
#  49  instant_bookable                              15051 non-null  object
#  50  calculated_host_listings_count                15051 non-null  int64
#  51  calculated_host_listings_count_entire_homes   15051 non-null  int64
#  52  calculated_host_listings_count_private_rooms  15051 non-null  int64
#  53  calculated_host_listings_count_shared_rooms   15051 non-null  int64
#  54  reviews_per_month                             11807 non-null  float64
# dtypes: float64(13), int64(18), object(24)
# memory usage: 6.3+ MB

# %% [markdown]
# ## 3.2 Covert Data Types
#
# - Convert price column to numeric values for better analysis
# - Convert boolean columns to the proper data type.

# %%
# Check columns with data type = object
object_columns = df_listings.select_dtypes(include=['object']).columns
print("\n----Object Columns:\n")
print(object_columns)
# Out:
# ----Object Columns:
#
# Index(['listing_url', 'name', 'description', 'neighborhood_overview',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_identity_verified', 'neighbourhood_cleansed',
#        'property_type', 'room_type', 'bathrooms_text', 'amenities', 'price',
#        'has_availability', 'first_review', 'last_review', 'instant_bookable'],
#       dtype='object')

# %%
# Change data types of specific columns

cols_to_string = [
    'listing_url',
    'name',
    'description',
    'neighborhood_overview',
    'host_url',
    'host_name',
    'host_location',
    'host_about',
    'bathrooms_text',
    'neighbourhood_cleansed'
]

cols_to_category = [
    'host_response_time',
    'property_type',
    'room_type'
]

cols_to_datetime = [
    'host_since',
    'first_review',
    'last_review'
]

cols_rate = [
    'host_response_rate',
    'host_acceptance_rate'
]

cols_price = [
    'price'
]

cols_to_boolean = [
    'host_is_superhost',
    'host_identity_verified',
    'has_availability',
    'instant_bookable'
]

# Convert columns to appropriate data types
df_listings[cols_to_string] = df_listings[cols_to_string].astype('string')

df_listings[cols_to_category] = df_listings[cols_to_category].astype('category')

df_listings[cols_to_datetime] = df_listings[cols_to_datetime].apply(pd.to_datetime, format='%Y-%m-%d')

df_listings[cols_rate] = df_listings[cols_rate].apply(
    lambda col: col.str.replace('%', '', regex=True).astype(float) / 100
)

df_listings[cols_to_boolean] = df_listings[cols_to_boolean].applymap(
    lambda x: True if str(x).lower() in ['t', 'true', '1'] else False
).astype('boolean')


# Print the data types after conversion
print("\n----Data Types After Conversion:\n")
print(df_listings.dtypes)
# Out:
# ----Data Types After Conversion:
#
# id                                                       int64
# listing_url                                     string[python]
# name                                            string[python]
# description                                     string[python]
# neighborhood_overview                           string[python]
# host_id                                                  int64
# host_url                                        string[python]
# host_name                                       string[python]
# host_since                                      datetime64[ns]
# host_location                                   string[python]
# host_about                                      string[python]
# host_response_time                                    category
# host_response_rate                                     float64
# host_acceptance_rate                                   float64
# host_is_superhost                                      boolean
# host_listings_count                                      int64
# host_total_listings_count                                int64
# host_identity_verified                                 boolean
# neighbourhood_cleansed                          string[python]
# latitude                                               float64
# longitude                                              float64
# property_type                                         category
# room_type                                             category
# accommodates                                             int64
# bathrooms                                              float64
# bathrooms_text                                  string[python]
# bedrooms                                               float64
# beds                                                   float64
# amenities                                               object
# price                                                   object
# minimum_nights                                           int64
# maximum_nights                                           int64
# has_availability                                       boolean
# availability_30                                          int64
# availability_60                                          int64
# availability_90                                          int64
# availability_365                                         int64
# number_of_reviews                                        int64
# number_of_reviews_ltm                                    int64
# number_of_reviews_l30d                                   int64
# first_review                                    datetime64[ns]
# last_review                                     datetime64[ns]
# review_scores_rating                                   float64
# review_scores_accuracy                                 float64
# review_scores_cleanliness                              float64
# review_scores_checkin                                  float64
# review_scores_communication                            float64
# review_scores_location                                 float64
# review_scores_value                                    float64
# instant_bookable                                       boolean
# calculated_host_listings_count                           int64
# calculated_host_listings_count_entire_homes              int64
# calculated_host_listings_count_private_rooms             int64
# calculated_host_listings_count_shared_rooms              int64
# reviews_per_month                                      float64
# dtype: object
# /tmp/ipykernel_30146/1647529212.py:55: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_listings[cols_to_boolean] = df_listings[cols_to_boolean].applymap(

# %% [markdown]
# #### Observations:
#
# Some columns are lists (like amenities), but in the DataFrame they are set as object. So I learn that I can use ast.literal_eval to convert them to lists

# %%
# Convert 'amenities' column from string to list using ast.literal_eval
import ast
df_listings['amenities'] = df_listings['amenities'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else [])

# %%
# Check again the data types after conversion
for col, dtype in df_listings.dtypes.items():
    print(f"{col}: {dtype}")
# Out:
# id: int64
# listing_url: string
# name: string
# description: string
# host_id: int64
# host_url: string
# host_name: string
# host_since: datetime64[ns]
# host_response_time: string
# host_response_rate: float64
# host_acceptance_rate: float64
# host_is_superhost: boolean
# host_listings_count: int64
# host_total_listings_count: int64
# host_identity_verified: boolean
# neighbourhood: string
# neighbourhood_cleansed: string
# latitude: float64
# longitude: float64
# property_type: category
# room_type: category
# accommodates: int64
# bathrooms: float64
# bathrooms_text: string
# bedrooms: float64
# beds: float64
# amenities: object
# price: float64
# minimum_nights: int64
# maximum_nights: int64
# has_availability: boolean
# availability_30: int64
# availability_60: int64
# availability_90: int64
# availability_365: int64
# number_of_reviews: int64
# number_of_reviews_ltm: int64
# number_of_reviews_l30d: int64
# first_review: datetime64[ns]
# last_review: datetime64[ns]
# review_scores_rating: float64
# review_scores_accuracy: float64
# review_scores_cleanliness: float64
# review_scores_checkin: float64
# review_scores_communication: float64
# review_scores_location: float64
# review_scores_value: float64
# instant_bookable: boolean
# calculated_host_listings_count: int64
# calculated_host_listings_count_entire_homes: int64
# calculated_host_listings_count_private_rooms: int64
# calculated_host_listings_count_shared_rooms: int64
# reviews_per_month: float64

# %% [markdown]
# ## 2.4 Handle missing values
#
# Drop rows or columns with too many missing values and fill or impute others as needed.
# python. First I'll check the columns with missing values.

# %%
# Check for missing values
missing_values = df_listings.isnull().sum()
print("Missing values in each column:")
print(missing_values[missing_values > 0])
# Out:
# Missing values in each column:
# description                     518
# host_response_time             2871
# host_response_rate             2871
# host_acceptance_rate           2415
# host_is_superhost               332
# neighbourhood                  9463
# bathrooms                      1998
# bathrooms_text                   24
# bedrooms                        794
# beds                           2007
# price                          1989
# has_availability               1081
# first_review                   3244
# last_review                    3244
# review_scores_rating           3244
# review_scores_accuracy         3244
# review_scores_cleanliness      3244
# review_scores_checkin          3244
# review_scores_communication    3244
# review_scores_location         3245
# review_scores_value            3244
# reviews_per_month              3244
# dtype: int64

# %% [markdown]
# #### Observation
#
# There are some relevant columns with missing values:
# - **`price`**: 1989 nulls
# - **review_scores** and **dates of reviews**: 3244 (probably corresponding to new listings without reviews)
# - **beds** and **bathrooms**: This data is added by the host, maybe in some cases they don't typoe in correctly, so for the analysis is not neccessarily relevant the missing data in these columns.
# - **host**, **host_rates**: This can also correspond to new hosts, that's why they are empty.
#
# *Price is relevant for the analysis, so let's check this out*

# %%
# Check listings with missing price
missing_price_listings = df_listings[df_listings['price'].isnull()]
print("Listings with missing price:")
print(missing_price_listings[['listing_url', 'price', 'has_availability']])
# Out:
# Listings with missing price:
#                                             listing_url  price  \
# 9                   https://www.airbnb.com/rooms/844274    NaN
# 11                   https://www.airbnb.com/rooms/65058    NaN
# 12                   https://www.airbnb.com/rooms/73752    NaN
# 13                   https://www.airbnb.com/rooms/80482    NaN
# 17                   https://www.airbnb.com/rooms/95139    NaN
# ...                                                 ...    ...
# 14315  https://www.airbnb.com/rooms/1299604714927560324    NaN
# 14321  https://www.airbnb.com/rooms/1298759807866003043    NaN
# 14337  https://www.airbnb.com/rooms/1298830859711843500    NaN
# 14339  https://www.airbnb.com/rooms/1298876065698878881    NaN
# 14341  https://www.airbnb.com/rooms/1298884979272174903    NaN
#
#        has_availability
# 9                  <NA>
# 11                 <NA>
# 12                 <NA>
# 13                 <NA>
# 17                 <NA>
# ...                 ...
# 14315              True
# 14321              True
# 14337              True
# 14339              True
# 14341              True
#
# [1989 rows x 3 columns]

# %% [markdown]
# #### Observations
#
# After clicking in some of the listings with missing values in price column, I can see that they don't have any date available, so probably they are no active listings.
#
# Considering that price is an important value for future analysis, and that some of the listings are probably not available, I will filter out those rows from the dataframe

# %%
# drop rows with missing price
df_listings.dropna(subset=['price'], inplace=True)

# %% [markdown]
# For the rest of the columns with missing values:
#
# - Fill with 'no description' or 'unknown'
#     - description
#     - neighbourhood
#     - host_response_time
#     - host_response_rate
#     - host_acceptance_rate'
#
# The rest of the columns have data that is not relevant if some values are missing.
# For example bathrooms, beds,
# For reviews, probably the listings are new and they don't have reviews yet.

# %%
# Fill missing values in description and neighborhood_overview with 'no description'
df_listings['description'] = df_listings['description'].fillna('No description')
df_listings['neighbourhood'] = df_listings['neighbourhood'].fillna('Unknown')

# Fill missing values in response time/rate with 'Unknown'
df_listings['host_response_time'] = df_listings['host_response_time'].fillna('Unknown')
df_listings['host_response_rate'] = df_listings['host_response_rate'].fillna(0.0)
df_listings['host_acceptance_rate'] = df_listings['host_acceptance_rate'].fillna(0.0)

# Fill missing values in host name with 'Unknown'
df_listings['host_name'] = df_listings['host_name'].fillna('Unknown')

# %% [markdown]
# ## 3. Analysis of prices
#
# Here I'll start a general analysis of the prices to check if some extra transformations are needed.
#
# ### 3.1 Summary
#
# Here we will explore the prices range

# %%
# Summary statistics for price
print(df_listings['price'].describe())
print("99th percentile:", df_listings['price'].quantile(0.99))
# Out:
# count    1.306200e+04
# mean     8.535579e+04
# std      9.882005e+05
# min      7.762000e+03
# 25%      3.156425e+04
# 50%      4.385700e+04
# 75%      6.500000e+04
# max      9.692788e+07
# Name: price, dtype: float64
# 99th percentile: 500000.0

# %% [markdown]
# #### Observations
#
# - Prices range from 7,762 CLP to 97 million. The lower price seems reasonably, but the highest is definitely an outlier or data entry mistake.
# - The average price is about 85,356 CLP
# - Standard deviation = 988,200.5. This shows there is a huge spread/variability in prices — the values vary widely from the average so there are very large outliers
# - 99% of the listings have a price below 500,000 CLP

# %% [markdown]
# ### 3.2 Visualizing Price Distribution
#
# We'll plot a histogram of prices corresponding to the percentile 99

# %%
# Histogram of the 'price' column (max 500,000 CLP)

import matplotlib.pyplot as plt

#Filter prices to a maximum of 500,000 CLP
reasonable_prices = df_listings[df_listings['price'] <= 500000]['price']

plt.figure(figsize=(10, 6))
plt.hist(reasonable_prices, bins=100, color='blue', alpha=0.7)
plt.title('Distribution of Prices in Santiago Listings (up to 500,000 CLP)')
plt.xlabel('Price')
plt.ylabel('Number of Listings')
plt.yscale('log')  # Use logarithmic scale for better visibility
plt.show()

# %% [markdown]
# And now a histogram of prices corresponding to the percentile 75

# %%
# Histogram of the 'price' column (75% of listings)

import matplotlib.pyplot as plt

#Filter prices to a maximum of percentile 76
prices_median = df_listings[df_listings['price'] <= df_listings['price'].quantile(0.75)]['price']

plt.figure(figsize=(10, 6))
plt.hist(prices_median, bins=50, color='blue', alpha=0.7)
plt.title('Distribution of Prices in Santiago Listings (up to 65,000 CLP)')
plt.xlabel('Price')
plt.ylabel('Number of Listings')
plt.show()

# %% [markdown]
# Hewre I should add some observations about the histogram

# %% [markdown]
# I was curious to see what kind of listings had prices over 500,000 CLP per night (which is very expensive for Santiago. Even for a luxury place sounds like too much.)
# So I am checking the url listings, to check on the Airbnb Website some of the listings

# %%
# Check listings with price greater than 500000 

high_price_listings = df_listings[df_listings['price'] > 500000]
print("Listings with price greater than 500000:")
print(high_price_listings[['listing_url', 'price']])
# Out:
# Listings with price greater than 500000:
#                                             listing_url       price
# 144                 https://www.airbnb.com/rooms/529207    593436.0
# 237                https://www.airbnb.com/rooms/4539250  18609607.0
# 298                https://www.airbnb.com/rooms/3694354    593436.0
# 313                https://www.airbnb.com/rooms/3826466   1186872.0
# 368                https://www.airbnb.com/rooms/5418047    593436.0
# ...                                                 ...         ...
# 13266  https://www.airbnb.com/rooms/1259753279420806992    767520.0
# 13798  https://www.airbnb.com/rooms/1282609732909070860   1000000.0
# 14013  https://www.airbnb.com/rooms/1288340241426105476    653907.0
# 14125  https://www.airbnb.com/rooms/1291230327012921884   3485714.0
# 14479  https://www.airbnb.com/rooms/1304327791338910289    642857.0
#
# [125 rows x 2 columns]

# %% [markdown]
# #### Observations
#
# There are 125 listings where the price is over 500,000 CLP per night.
# I randomly chose a few of them.
#
# For example:
# Row 237: The price is actually high on the website, but I can see in the description that this person is searching for a roommate to rent out a room in the apartment for 280,000 CLP per month. But they price per night is listed as 18 million CLP.
#
# Row 13266: This is an apartment in Valle Nevado, which is a fancy place up in the mountains by a ski center.
#
# Row 14125: This one must be a mistake, because the listing on the website have a price per night around 65,000 CLP
#
# Since there are 125 rows over 500,000 I cant check them one by one. Some of them can be a real price (like a luxury apartment in Valle Nevado), or a mistake.
# For further analysis, I will flag these rows, but I won't delete them from the dataFrame

# %% [markdown]
# ## 3.3 Flag outliers
#
# To keep the integrity of the data, I decided to not delete the rows with extremly high prices, but flag them. Some can actually be real prices, so I want to keep them in the analysis

# %%
# Flag listings with price greater than 500,000 CLP
df_listings['high_price_flag'] = df_listings['price'] > 500000

# Prtint the number of listings with high price flag
print(f"Number of listings with high price flag: {df_listings['high_price_flag'].sum()}")
# Out:
# Number of listings with high price flag: 125

# %% [markdown]
# ## 4. Final transformations
#
# The DataFrame contains many columns, so now I will go through them to see if I keep or drop them. Also I need to check the column names.

# %%
# check neighbourhoods and neighbourhood_cleansed
print("Unique neighbourhoods:")
print(df_listings['neighbourhood'].unique())
print("Unique neighbourhood_cleansed:")
print(df_listings['neighbourhood_cleansed'].unique())
# Out:
# Unique neighbourhoods:
# <StringArray>
# [                                                    'Unknown',
#                     'Providencia, Región Metropolitana, Chile',
#                'Santiago, Santiago Metropolitan Region, Chile',
#                        'Santiago, Región Metropolitana, Chile',
#           'Providencia, Santiago, Región Metropolitana, Chile',
#                      'Las Condes, Región Metropolitana, Chile',
#                        'Recoleta, Región Metropolitana, Chile',
#                        'La Reina, Región Metropolitana, Chile',
#              'Las Condes Santiago, Metropolitan Region, Chile',
#                                              'La Parva, Chile',
#  ...
#  'Las Condes, Santiago de Chile , Región Metropolitana, Chile',
#                 'Calera de Tango, Región Metropolitana, Chile',
#                 'Ñuñoa, Santiago, Región Metropolitana, Chile',
#             'Pedro Aguirre Cerda, Región Metropolitana, Chile',
#                       'Cerrillos, Región Metropolitana, Chile',
#                              'Santiago,  Metropolitana, Chile',
#                                   'Limache, Valparaíso, Chile',
#                                            'Valparaiso, Chile',
#                     'Las Condes , Región Metropolitana, Chile',
#            'Las Condes, Santiago, Región Metropolitana, Chile']
# Length: 134, dtype: string
# Unique neighbourhood_cleansed:
# <StringArray>
# [        'Providencia',        'Lo Barnechea',            'La Reina',
#             'Santiago',          'Las Condes',               'Ñuñoa',
#             'Recoleta',            'Vitacura',           'Peñalolén',
#           'San Miguel',    'Estación Central', 'Pedro Aguirre Cerda',
#          'San Joaquín',          'La Florida',               'Macul',
#                'Maipú',       'Independencia',         'La Cisterna',
#             'Pudahuel',       'Quinta Normal',           'Cerrillos',
#           'Huechuraba',               'Renca',           'La Granja',
#             'Conchalí',           'Quilicura',            'Lo Prado',
#            'El Bosque',         'Cerro Navia',           'San Ramón',
#           'La Pintana']
# Length: 31, dtype: string

# %% [markdown]
# So after checking the columns related to nneighbourhood_cleansed and neighbourhood, I will keep only the cleansed one, because it is easier to work with. The information on the dataset corresponds to Santiago, so I don't need to know thee region and coutry.

# %%
# drop neighbourhood column
df_listings.drop(columns=['neighbourhood'], inplace=True)

# %% [markdown]
# According to this, I'll keep the calculated_host_listing_count
#
#
# | Column                           | Description                                                                |
# | -------------------------------- | -------------------------------------------------------------------------- |
# | `host_listings_count`            | Often self-reported — the number of listings the host claims to have       |
# | `calculated_host_listings_count` | Computed by Airbnb — likely more reliable as it's derived from actual data |

# %%
# Drop host_listings_count, host_total_listings_count
df_listings.drop(columns=['host_listings_count', 'host_total_listings_count'], inplace=True)

# %%
# Check the DataFrame after dropping columns
print("DataFrame after dropping unnecessary columns:")
print(df_listings.info())
# Out:
# DataFrame after dropping unnecessary columns:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13062 entries, 0 to 15050
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            13062 non-null  int64
#  1   listing_url                                   13062 non-null  string
#  2   name                                          13062 non-null  string
#  3   description                                   13062 non-null  string
#  4   host_id                                       13062 non-null  int64
#  5   host_url                                      13062 non-null  string
#  6   host_name                                     13062 non-null  string
#  7   host_since                                    13062 non-null  datetime64[ns]
#  8   host_response_time                            13062 non-null  string
#  9   host_response_rate                            13062 non-null  float64
#  10  host_acceptance_rate                          13062 non-null  float64
#  11  host_is_superhost                             12747 non-null  boolean
#  12  host_identity_verified                        13062 non-null  boolean
#  13  neighbourhood_cleansed                        13062 non-null  string
#  14  latitude                                      13062 non-null  float64
#  15  longitude                                     13062 non-null  float64
#  16  property_type                                 13062 non-null  category
#  17  room_type                                     13062 non-null  category
#  18  accommodates                                  13062 non-null  int64
#  19  bathrooms                                     13052 non-null  float64
#  20  bathrooms_text                                13050 non-null  string
#  21  bedrooms                                      13034 non-null  float64
#  22  beds                                          13043 non-null  float64
#  23  amenities                                     13062 non-null  object
#  24  price                                         13062 non-null  float64
#  25  minimum_nights                                13062 non-null  int64
#  26  maximum_nights                                13062 non-null  int64
#  27  has_availability                              12841 non-null  boolean
#  28  availability_30                               13062 non-null  int64
#  29  availability_60                               13062 non-null  int64
#  30  availability_90                               13062 non-null  int64
#  31  availability_365                              13062 non-null  int64
#  32  number_of_reviews                             13062 non-null  int64
#  33  number_of_reviews_ltm                         13062 non-null  int64
#  34  number_of_reviews_l30d                        13062 non-null  int64
#  35  first_review                                  10717 non-null  datetime64[ns]
#  36  last_review                                   10717 non-null  datetime64[ns]
#  37  review_scores_rating                          10717 non-null  float64
#  38  review_scores_accuracy                        10717 non-null  float64
#  39  review_scores_cleanliness                     10717 non-null  float64
#  40  review_scores_checkin                         10717 non-null  float64
#  41  review_scores_communication                   10717 non-null  float64
#  42  review_scores_location                        10716 non-null  float64
#  43  review_scores_value                           10717 non-null  float64
#  44  instant_bookable                              13062 non-null  boolean
#  45  calculated_host_listings_count                13062 non-null  int64
#  46  calculated_host_listings_count_entire_homes   13062 non-null  int64
#  47  calculated_host_listings_count_private_rooms  13062 non-null  int64
#  48  calculated_host_listings_count_shared_rooms   13062 non-null  int64
#  49  reviews_per_month                             10717 non-null  float64
#  50  high_price_flag                               13062 non-null  bool
# dtypes: bool(1), boolean(4), category(2), datetime64[ns](3), float64(16), int64(16), object(1), string(8)
# memory usage: 4.6+ MB
# None

# %% [markdown]
# Last thing, I will change some column names

# %%
# Rename columns for consistency

df_listings.rename(columns={
    "id": "listing_id",
    "price": "price_clp",
    "host_is_superhost": "is_superhost",
    "calculated_host_listings_count": "host_total_listings_count",
    "calculated_host_listings_count_entire_homes": "host_entire_home_count",
    "calculated_host_listings_count_private_rooms": "host_private_room_count",
    "calculated_host_listings_count_shared_rooms": "host_shared_room_count"
}, inplace=True)

# %% [markdown]
# One last thing I just remember, I will add a calculated price in dollars for a better undestanding of the prices for people who are not familiar with chilean peso currency

# %%
# Add a column price_usd after the column listing_price_clp

conversion_rate = 0.0011

df_listings['price_usd'] = df_listings['price_clp'] * conversion_rate

# Reorder columns to place listing_price_usd after listing_price_clp
columns = df_listings.columns.tolist()
price_clp_index = columns.index('price_clp')
columns.insert(price_clp_index + 1, columns.pop(columns.index('price_usd')))
df_listings = df_listings[columns]

# %%
# Check DataFrame after renaming columns
print("DataFrame after renaming columns:")

print(df_listings.info())
# Out:
# DataFrame after renaming columns:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13062 entries, 0 to 15050
# Data columns (total 52 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   listing_id                   13062 non-null  int64
#  1   listing_url                  13062 non-null  string
#  2   name                         13062 non-null  string
#  3   description                  13062 non-null  string
#  4   host_id                      13062 non-null  int64
#  5   host_url                     13062 non-null  string
#  6   host_name                    13062 non-null  string
#  7   host_since                   13062 non-null  datetime64[ns]
#  8   host_response_time           13062 non-null  string
#  9   host_response_rate           13062 non-null  float64
#  10  host_acceptance_rate         13062 non-null  float64
#  11  is_superhost                 12747 non-null  boolean
#  12  host_identity_verified       13062 non-null  boolean
#  13  neighbourhood_cleansed       13062 non-null  string
#  14  latitude                     13062 non-null  float64
#  15  longitude                    13062 non-null  float64
#  16  property_type                13062 non-null  category
#  17  room_type                    13062 non-null  category
#  18  accommodates                 13062 non-null  int64
#  19  bathrooms                    13052 non-null  float64
#  20  bathrooms_text               13050 non-null  string
#  21  bedrooms                     13034 non-null  float64
#  22  beds                         13043 non-null  float64
#  23  amenities                    13062 non-null  object
#  24  price_clp                    13062 non-null  float64
#  25  price_usd                    13062 non-null  float64
#  26  minimum_nights               13062 non-null  int64
#  27  maximum_nights               13062 non-null  int64
#  28  has_availability             12841 non-null  boolean
#  29  availability_30              13062 non-null  int64
#  30  availability_60              13062 non-null  int64
#  31  availability_90              13062 non-null  int64
#  32  availability_365             13062 non-null  int64
#  33  number_of_reviews            13062 non-null  int64
#  34  number_of_reviews_ltm        13062 non-null  int64
#  35  number_of_reviews_l30d       13062 non-null  int64
#  36  first_review                 10717 non-null  datetime64[ns]
#  37  last_review                  10717 non-null  datetime64[ns]
#  38  review_scores_rating         10717 non-null  float64
#  39  review_scores_accuracy       10717 non-null  float64
#  40  review_scores_cleanliness    10717 non-null  float64
#  41  review_scores_checkin        10717 non-null  float64
#  42  review_scores_communication  10717 non-null  float64
#  43  review_scores_location       10716 non-null  float64
#  44  review_scores_value          10717 non-null  float64
#  45  instant_bookable             13062 non-null  boolean
#  46  host_total_listings_count    13062 non-null  int64
#  47  host_entire_home_count       13062 non-null  int64
#  48  host_private_room_count      13062 non-null  int64
#  49  host_shared_room_count       13062 non-null  int64
#  50  reviews_per_month            10717 non-null  float64
#  51  high_price_flag              13062 non-null  bool
# dtypes: bool(1), boolean(4), category(2), datetime64[ns](3), float64(17), int64(16), object(1), string(8)
# memory usage: 4.7+ MB
# None

# %%
# Save the cleaned DataFrame to a new CSV file
import os
output_dir = 'cleaned_data'
os.makedirs(output_dir, exist_ok=True)
# Save the cleaned DataFrame to a new CSV file (not compressed)
df_listings.to_csv(os.path.join(output_dir, 'listings_cleaned.csv'), index=False)
